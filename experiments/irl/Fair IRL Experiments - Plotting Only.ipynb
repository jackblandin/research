# %% [markdown]
# # Setup

# %%
# Add parent directory to current path. Needed for research imports.
import os.path
import sys
p = os.path.abspath('../..')
if p not in sys.path:
    sys.path.insert(0,p)

# Enable hot reloading
# %load_ext autoreload
# %autoreload 2


import logging
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings

from experiments.irl.datasets import *
from experiments.irl.experiment_utils import *
from research.irl.fair_irl import *
from research.utils import *


logging.basicConfig(level=logging.INFO)
warnings.filterwarnings('ignore')

sns.set_style('darkgrid')

from IPython.display import display, HTML
display(HTML("<style>.container { width:2000px !important; }</style>"))
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_colwidth', None)

# Prevent long logging lines from wrapping
# display(HTML("<style>div.output_area pre {white-space: pre;}</style>"))
np.set_printoptions(linewidth=np.inf)
# Out:
# <style>.container { width:2000px !important; }</style>

# %% [markdown]
# # Run experiments

# %% [markdown]
# ### Boston to Adult

# %%
base_exp_info = {
#     'EXPERIMENT_NAME': 'compas_48_hidden',
    'EXPERIMENT_NAME': 'boston_to_adult_jan8_44',
#     'EXPERIMENT_NAME': 'adult_to_boston_jan8_33',
#     'EXPERIMENT_NAME': 'COMPAS_to_boston_jan8_32',
    
    'FEAT_EXP_OBJECTIVE_NAMES': [
        'Acc',
#         'AccPar',
        'DemPar',
        'EqOpp',
#         'FPRPar',
        'TNRPar',
#         'FNRPar',
        'PR_Z0',
        'PR_Z1',
        'NR_Z0',
        'NR_Z1',
        'TPR_Z0',
        'TPR_Z1',
        'TNR_Z0',
        'TNR_Z1',
#         'FPR_Z0',
#         'FPR_Z1',
#         'FNR_Z0',
#         'FNR_Z1',
    ],
    'PERF_MEAS_OBJECTIVE_NAMES': [
        'Acc',
        'DemPar',
        'EqOpp',
        'FPRPar',
        'TNRPar',
        'FNRPar',
#         'PR_Z0',
#         'PR_Z1',
#         'TPR_Z0',
#         'TPR_Z1',
#         'TNR_Z0',
#         'TNR_Z1',
#         'FPR_Z0',
#         'FPR_Z1',
#         'FNR_Z0',
#         'FNR_Z1',
        'PredPar',
        'NegPredPar',
    ],
    
    # Expert demo parameters
#     'DATASET': 'ACSIncome__CA',
#     'TARGET_DATASET': 'ACSIncome__IL',
    
    'EXPERT_CANNOT_PREDICT_IN_TARGET': False,
    'USE_HIDDEN_FEATURES_SOURCE': True,
    'USE_HIDDEN_FEATURES_TARGET': False,
    
    'N_EXPERT_DEMOS': 1,
    'EXPERT_ALGO': None,
    'N_DATASET_SAMPLES': 100_000,
    'MIN_FREQ_FILL_PCT': .3,
    'RESTRICT_Y_ACTION': True,
    # IRL Loop parameters
    'IRL_METHOD': None,
    'METHOD': 'highs',
    # Plotting parameters
    'NOISE_FACTOR': .01,
    'ANNOTATE': True,
    'N_INIT_POLICIES': 3,
    'NON_EXPERT_ALGOS': [
        'OptAccNoisy',
        'HardtDemParNoisy',
        'HardtEqOppNoisy',
#         'HardtFPRNoisy',
#         'HardtTNRNoisy',
#         'Dummy',
#         'DummyNoisy',
    ],
}

base_exp_info['N_TRIALS'] = 23
# base_exp_info['IGNORE_RESULTS_EPSILON'] = .06
base_exp_info['EPSILON'] = .005
base_exp_info['IGNORE_RESULTS_EPSILON'] = .01
base_exp_info['MAX_ITER'] = 40
base_exp_info['ALLOW_NEG_WEIGHTS'] = True
base_exp_info['DOT_WEIGHTS_FEAT_EXP'] = True
base_exp_info['EARLY_STOP_NO_NEW_BEST_ITERS'] = 15

source_states = [
#     'ACSIncome__AL',
#     'ACSIncome__CA',
#     'ACSIncome__FL',
#     'ACSIncome__IL',
#     'ACSIncome__ME',
#     'ACSIncome__NY',
#     'ACSIncome__TX',
#     'ACSIncome__WA',
#     'Adult',
#     'COMPAS',
    'Boston',
]

target_states = [
#     'ACSIncome__AL',
#     'ACSIncome__CA',
#     'ACSIncome__FL',
#     'ACSIncome__IL',
#     'ACSIncome__ME',
#     'ACSIncome__NY',
#     'ACSIncome__TX',
#     'ACSIncome__TX',
    'Adult',
#     'Boston',
#     'COMPAS',
]

# %% [markdown]
# ### Adult to Boston

# %%
base_exp_info = {
#     'EXPERIMENT_NAME': 'compas_48_hidden',
#     'EXPERIMENT_NAME': 'boston_to_adult_jan8_44',
#     'EXPERIMENT_NAME': 'adult_to_boston_jan8_44',
    'EXPERIMENT_NAME': 'adult_to_boston_error_inc_stop_59',
#     'EXPERIMENT_NAME': 'COMPAS_to_boston_jan8_32',
    
    'FEAT_EXP_OBJECTIVE_NAMES': [
        'Acc',
#         'AccPar',
        'DemPar',
        'EqOpp',
#         'FPRPar',
        'TNRPar',
#         'FNRPar',
        'PR_Z0',
        'PR_Z1',
#         'NR_Z0',
#         'NR_Z1',
#         'TPR_Z0',
#         'TPR_Z1',
#         'TNR_Z0',
#         'TNR_Z1',
#         'FPR_Z0',
#         'FPR_Z1',
#         'FNR_Z0',
#         'FNR_Z1',
    ],
    'PERF_MEAS_OBJECTIVE_NAMES': [
        'Acc',
        'DemPar',
        'EqOpp',
        'FPRPar',
        'TNRPar',
        'FNRPar',
#         'PR_Z0',
#         'PR_Z1',
#         'TPR_Z0',
#         'TPR_Z1',
#         'TNR_Z0',
#         'TNR_Z1',
#         'FPR_Z0',
#         'FPR_Z1',
#         'FNR_Z0',
#         'FNR_Z1',
        'PredPar',
        'NegPredPar',
    ],
    
    # Expert demo parameters
#     'DATASET': 'ACSIncome__CA',
#     'TARGET_DATASET': 'ACSIncome__IL',
    
    'EXPERT_CANNOT_PREDICT_IN_TARGET': False,
    'USE_HIDDEN_FEATURES_SOURCE': True,
    'USE_HIDDEN_FEATURES_TARGET': False,
    
    'N_EXPERT_DEMOS': 1,
    'EXPERT_ALGO': None,
    'N_DATASET_SAMPLES': 100_000,
    'MIN_FREQ_FILL_PCT': .3,
    'RESTRICT_Y_ACTION': True,
    # IRL Loop parameters
    'IRL_METHOD': None,
    'METHOD': 'highs',
    # Plotting parameters
    'NOISE_FACTOR': .01,
    'ANNOTATE': True,
    'N_INIT_POLICIES': 1,
    'NON_EXPERT_ALGOS': [
        'OptAccNoisy',
#         'HardtDemParNoisy',
#         'HardtEqOppNoisy',
#         'HardtFPRNoisy',
#         'HardtTNRNoisy',
#         'Dummy',
#         'DummyNoisy',
    ],
}

base_exp_info['N_TRIALS'] = 5
# base_exp_info['IGNORE_RESULTS_EPSILON'] = .06
base_exp_info['EPSILON'] = .005
base_exp_info['IGNORE_RESULTS_EPSILON'] = .5
base_exp_info['MAX_ITER'] = 40
base_exp_info['ALLOW_NEG_WEIGHTS'] = True
base_exp_info['DOT_WEIGHTS_FEAT_EXP'] = True
base_exp_info['EARLY_STOP_NO_NEW_BEST_ITERS'] = 15

source_states = [
#     'ACSIncome__AL',
#     'ACSIncome__CA',
#     'ACSIncome__FL',
#     'ACSIncome__IL',
#     'ACSIncome__ME',
#     'ACSIncome__NY',
#     'ACSIncome__TX',
#     'ACSIncome__WA',
    'Adult',
#     'COMPAS',
#     'Boston',
]

target_states = [
#     'ACSIncome__AL',
#     'ACSIncome__CA',
#     'ACSIncome__FL',
#     'ACSIncome__IL',
#     'ACSIncome__ME',
#     'ACSIncome__NY',
#     'ACSIncome__TX',
#     'ACSIncome__TX',
#     'Adult',
    'Boston',
#     'COMPAS',
]

# %% [markdown]
# ### ACSIncome: State to State MA to MS

# %% [markdown]
# ### ACSIncome: State to State MS to MA

# %%
base_exp_info = {
#     'EXPERIMENT_NAME': 'compas_48_hidden',
#     'EXPERIMENT_NAME': 'boston_to_adult_jan8_44',
#     'EXPERIMENT_NAME': 'adult_to_boston_jan8_33',
#     'EXPERIMENT_NAME': 'COMPAS_to_boston_jan8_32',
#     'EXPERIMENT_NAME': 'ACSIncome_CA_to_WY_jan8_44',
    'EXPERIMENT_NAME': 'ACSIncome_MA_to_MS_jan8_44',
    
    'FEAT_EXP_OBJECTIVE_NAMES': [
        'Acc',
#         'AccPar',
        'DemPar',
        'EqOpp',
#         'FPRPar',
        'TNRPar',
#         'FNRPar',
        'PR_Z0',
        'PR_Z1',
        'NR_Z0',
        'NR_Z1',
        'TPR_Z0',
        'TPR_Z1',
        'TNR_Z0',
        'TNR_Z1',
#         'FPR_Z0',
#         'FPR_Z1',
#         'FNR_Z0',
#         'FNR_Z1',
    ],
    'PERF_MEAS_OBJECTIVE_NAMES': [
        'Acc',
        'DemPar',
        'EqOpp',
        'FPRPar',
        'TNRPar',
        'FNRPar',
#         'PR_Z0',
#         'PR_Z1',
#         'TPR_Z0',
#         'TPR_Z1',
#         'TNR_Z0',
#         'TNR_Z1',
#         'FPR_Z0',
#         'FPR_Z1',
#         'FNR_Z0',
#         'FNR_Z1',
        'PredPar',
        'NegPredPar',
    ],
    
    # Expert demo parameters
#     'DATASET': 'ACSIncome__CA',
#     'TARGET_DATASET': 'ACSIncome__IL',
    
    'EXPERT_CANNOT_PREDICT_IN_TARGET': False,
    'USE_HIDDEN_FEATURES_SOURCE': True,
    'USE_HIDDEN_FEATURES_TARGET': False,
    
    'N_EXPERT_DEMOS': 1,
    'EXPERT_ALGO': None,
    'N_DATASET_SAMPLES': 40_000,
    'MIN_FREQ_FILL_PCT': .35,
    'RESTRICT_Y_ACTION': True,
    # IRL Loop parameters
    'IRL_METHOD': None,
    'METHOD': 'highs',
    # Plotting parameters
    'NOISE_FACTOR': .01,
    'ANNOTATE': True,
    'N_INIT_POLICIES': 1,
    'NON_EXPERT_ALGOS': [
        'OptAccNoisy',
#         'HardtDemParNoisy',
#         'HardtEqOppNoisy',
#         'HardtFPRNoisy',
#         'HardtTNRNoisy',
#         'Dummy',
#         'DummyNoisy',
    ],
}

base_exp_info['N_TRIALS'] = 2
# base_exp_info['IGNORE_RESULTS_EPSILON'] = .06
base_exp_info['EPSILON'] = .015
base_exp_info['IGNORE_RESULTS_EPSILON'] = .025
base_exp_info['MAX_ITER'] = 40
base_exp_info['ALLOW_NEG_WEIGHTS'] = True
base_exp_info['DOT_WEIGHTS_FEAT_EXP'] = True
base_exp_info['EARLY_STOP_NO_NEW_BEST_ITERS'] = 15

source_states = [
#     'ACSIncome__AL',
#     'ACSIncome__CA',
#     'ACSIncome__FL',
#     'ACSIncome__IL',
#     'ACSIncome__ME',
#     'ACSIncome__NY',
#     'ACSIncome__TX',
    'ACSIncome__MA',
#     'Adult',
#     'COMPAS',
#     'Boston',
]

target_states = [
#     'ACSIncome__AL',
#     'ACSIncome__CA',
#     'ACSIncome__FL',
#     'ACSIncome__IL',
#     'ACSIncome__ME',
#     'ACSIncome__NY',
#     'ACSIncome__TX',
    'ACSIncome__MS',
#     'Adult',
#     'Boston',
#     'COMPAS',
]

# %%
base_exp_info = {
#     'EXPERIMENT_NAME': 'compas_48_hidden',
#     'EXPERIMENT_NAME': 'boston_to_adult_jan8_44',
#     'EXPERIMENT_NAME': 'adult_to_boston_jan8_33',
#     'EXPERIMENT_NAME': 'COMPAS_to_boston_jan8_32',
#     'EXPERIMENT_NAME': 'ACSIncome_CA_to_WY_jan8_44',
    'EXPERIMENT_NAME': 'ACSIncome_MS_to_MA_jan8_44',
    
    'FEAT_EXP_OBJECTIVE_NAMES': [
        'Acc',
#         'AccPar',
        'DemPar',
        'EqOpp',
#         'FPRPar',
        'TNRPar',
#         'FNRPar',
        'PR_Z0',
        'PR_Z1',
        'NR_Z0',
        'NR_Z1',
        'TPR_Z0',
        'TPR_Z1',
        'TNR_Z0',
        'TNR_Z1',
#         'FPR_Z0',
#         'FPR_Z1',
#         'FNR_Z0',
#         'FNR_Z1',
    ],
    'PERF_MEAS_OBJECTIVE_NAMES': [
        'Acc',
        'DemPar',
        'EqOpp',
        'FPRPar',
        'TNRPar',
        'FNRPar',
#         'PR_Z0',
#         'PR_Z1',
#         'TPR_Z0',
#         'TPR_Z1',
#         'TNR_Z0',
#         'TNR_Z1',
#         'FPR_Z0',
#         'FPR_Z1',
#         'FNR_Z0',
#         'FNR_Z1',
        'PredPar',
        'NegPredPar',
    ],
    
    # Expert demo parameters
#     'DATASET': 'ACSIncome__CA',
#     'TARGET_DATASET': 'ACSIncome__IL',
    
    'EXPERT_CANNOT_PREDICT_IN_TARGET': False,
    'USE_HIDDEN_FEATURES_SOURCE': True,
    'USE_HIDDEN_FEATURES_TARGET': False,
    
    'N_EXPERT_DEMOS': 1,
    'EXPERT_ALGO': None,
    'N_DATASET_SAMPLES': 40_000,
    'MIN_FREQ_FILL_PCT': .35,
    'RESTRICT_Y_ACTION': True,
    # IRL Loop parameters
    'IRL_METHOD': None,
    'METHOD': 'highs',
    # Plotting parameters
    'NOISE_FACTOR': .01,
    'ANNOTATE': True,
    'N_INIT_POLICIES': 1,
    'NON_EXPERT_ALGOS': [
        'OptAccNoisy',
#         'HardtDemParNoisy',
#         'HardtEqOppNoisy',
#         'HardtFPRNoisy',
#         'HardtTNRNoisy',
#         'Dummy',
#         'DummyNoisy',
    ],
}

base_exp_info['N_TRIALS'] = 10
# base_exp_info['IGNORE_RESULTS_EPSILON'] = .06
base_exp_info['EPSILON'] = .015
base_exp_info['IGNORE_RESULTS_EPSILON'] = .04
base_exp_info['MAX_ITER'] = 40
base_exp_info['ALLOW_NEG_WEIGHTS'] = True
base_exp_info['DOT_WEIGHTS_FEAT_EXP'] = True
base_exp_info['EARLY_STOP_NO_NEW_BEST_ITERS'] = 15

source_states = [
#     'ACSIncome__AL',
#     'ACSIncome__CA',
#     'ACSIncome__FL',
#     'ACSIncome__IL',
#     'ACSIncome__ME',
#     'ACSIncome__NY',
#     'ACSIncome__TX',
    'ACSIncome__MS',
#     'Adult',
#     'COMPAS',
#     'Boston',
]

target_states = [
#     'ACSIncome__AL',
#     'ACSIncome__CA',
#     'ACSIncome__FL',
#     'ACSIncome__IL',
#     'ACSIncome__ME',
#     'ACSIncome__NY',
#     'ACSIncome__TX',
    'ACSIncome__MA',
#     'Adult',
#     'Boston',
#     'COMPAS',
]

# %% [markdown]
# ### Set Experts & Run

# %%
expert_algos = [
#     'OptAcc',
    'HardtDemPar',
    'HardtEqOpp',
#     'HardtTNRPar'
#     'HardtFPRPar',
    'HardtEqOdds',
    'BoundedGroupLoss',
#     'COMPAS',
]
        
experiments = []
for expert_algo in expert_algos:
    for source_dataset in source_states:
        for target_dataset in target_states:
            experiments.append({
                'EXPERT_ALGO': expert_algo,
                'IRL_METHOD': 'FairIRL',
                'DATASET': source_dataset,
                'TARGET_DATASET': target_dataset,
            })

# %%
exp_info = dict(base_exp_info)

# %% [markdown]
# # Compare results with source domain only

# %%
# !rm ../../data/experiment_output/fair_irl/exp_info/.DS_Store
# !rm ../../data/experiment_output/fair_irl/exp_results/.DS_Store
# Out:
# rm: ../../data/experiment_output/fair_irl/exp_info/.DS_Store: No such file or directory
# rm: ../../data/experiment_output/fair_irl/exp_results/.DS_Store: No such file or directory

# %%
# min_exp_timestamp = '2023-08-12 20:22:00'  # Cutoff for results of main text in AAAI submission   
if exp_info['EXPERIMENT_NAME'] == 'ACSIncome_MA_to_MS_jan8_44':
    min_exp_timestamp = '2024-01-11 18:36:00'
elif exp_info['EXPERIMENT_NAME'] == 'boston_to_adult_jan8_44':
    min_exp_timestamp = '2024-01-14 00:00:00'
else:
    min_exp_timestamp = '2024-01-01 00:00:00'  # Cutoff for results on Appendix D.4 (progressively increasing expert)

def skip_by_name(info):
    return 'EXPERIMENT_NAME' not in info or info['EXPERIMENT_NAME'] != base_exp_info['EXPERIMENT_NAME']

# %% [markdown]
# ### Compare each expert's demonstrations vs learned

# %%
# For folding
size_mult = 1.0
plt.rc('axes', titlesize=10*size_mult)     # fontsize of the axes title
plt.rc('axes', labelsize=10*size_mult, titlesize=10*size_mult)    # fontsize of the x and y axes labels
plt.rc('xtick', labelsize=10*size_mult)    # fontsize of the tick labels
plt.rc('ytick', labelsize=9*size_mult)    # fontsize of the tick labels
plt.rc('legend', fontsize=9*size_mult)    # legend fontsize
sns.set_style('whitegrid')

print('Experiment ID:', exp_info['EXPERIMENT_NAME'])
    
fig, axes, mu_dfs, w_dfs, perf_dfs = plot_results_source_domain_only(
    feat_objective_set_names=exp_info['FEAT_EXP_OBJECTIVE_NAMES'],
#     perf_objective_set_names=exp_info['PERF_MEAS_OBJECTIVE_NAMES'],
    perf_objective_set_names=[
        'Acc',
        'DemPar',
        'EqOpp',
        'FPRPar',
        'TNRPar',
        'FNRPar',
        'PredPar',
        'NegPredPar',
    ],
#     expert_algos=np.unique([exp['EXPERT_ALGO'] for exp in experiments]),
    expert_algos=[
#         'OptAcc',
        'HardtDemPar',
        'HardtEqOpp',
#         'HardtFPRPar',
#         'HardtFNRPar',
        'HardtEqOdds',
        'BoundedGroupLoss',
#         'COMPAS',
    ],
#     dataset=exp_info['DATASET'],
    dataset=None,
#     mu_noise_factor=.1,
    perf_noise_factor=0,
    w_noise_factor=0,
    mu_hue_order=[
        'muE',
        'muL (FairIRL)',
        'muL (Beh Clone)',
#         None,
#         None,
#         'muL (FairIRLFO)',
    ],
    perf_hue_order=[
        'Expert',
        'Learned (FairIRL)',
        'Learned (Beh Clone)',
#         None,
#         None,
    ],
    w_hue_order=[
#         None,
        'wL (FairIRL)',
#         None,
#         'wL (FairIRLFO)',
    ],
    extra_skip_conditions=skip_by_name,
    min_exp_timestamp=min_exp_timestamp,
#     max_mu_value=1,
#     min_w_value=-.05,
    mu_yticks=np.linspace(0, 1, 11).round(1),
    mu_ylim=(.1, 1.0),
    mu_whis=[1, 99],
    w_yticks = np.linspace(-1, 1, 21).round(2),
    w_ylim=(-.2, .4),
    w_whis=[1, 99],
    w_palette=[cp[1]],
    perf_ylim=(.3, 1.0),
    perf_yticks=np.linspace(0, 1, 11).round(2),
    perf_whis=[1, 99],
    min_perf_value=.6,
    size_mult=size_mult,
    figsize=(10, 8),
    palette=cp,
    mu_leg_ax=1,
    perf_leg_ax=0,
)

rotation = 60
if len(np.shape(axes)) > 1:
    for ax_i, _ in enumerate(axes[0]):
        axes[0][ax_i].tick_params(axis='x', rotation=rotation)
        axes[1][ax_i].tick_params(axis='x', rotation=rotation)
        axes[2][ax_i].tick_params(axis='x', rotation=rotation)
else:
    axes[0].tick_params(axis='x', rotation=rotation)
    axes[1].tick_params(axis='x', rotation=rotation)
    axes[2].tick_params(axis='x', rotation=rotation)
    
    
# axes[1][0].legend(labels=['$w^L$'])
axes[0][0].get_legend().get_texts()[0].set_text('$w^L$')

for i, label in enumerate(axes[1][1].get_legend().get_texts()):
    text = label.get_text()
    label.set_text(text.replace('(', '').replace(')', ''))
    

for i, label in enumerate(axes[2][0].get_legend().get_texts()):
    text = label.get_text()
    label.set_text(text.replace('Learned (', '').replace(')', ''))
    

for ax_i, ax in enumerate(axes):
    for plot_i, plot in enumerate(ax):
        title = plot.get_title()
        plot.set_title(title.replace('HardtEqOdds', 'EqOddsRed'))    

for i, _ in enumerate(axes[0]):
    labels = [item.get_text() for item in axes[0][i].get_xticklabels()]
#     labels[1] = labels[1].replace('DemPar', 'PRPar')
#     labels[2] = labels[2].replace('EqOpp', 'TPRPar')
    axes[0][i].set_xticklabels(labels)
    
for i, _ in enumerate(axes[1]):
    labels = [item.get_text() for item in axes[0][i].get_xticklabels()]
#     labels[1] = labels[1].replace('DemPar', 'PRPar')
#     labels[2] = labels[2].replace('EqOpp', 'TPRPar')
    axes[1][i].set_xticklabels(labels)

for i, _ in enumerate(axes[2]):
    labels = [item.get_text() for item in axes[2][i].get_xticklabels()]
#     labels[1] = labels[1].replace('DemPar', 'PRPar')
#     labels[2] = labels[2].replace('EqOpp', 'TPRPar')
    labels[-2] = labels[-2].replace('PredPar', 'PrPar')
    labels[-1] = labels[-1].replace('NegPredPar', 'NPrPar')
    axes[2][i].set_xticklabels(labels)
# Out:
# Experiment ID: adult_to_boston_error_inc_stop_57
# DATASET: None

# %% [markdown]
# ### Compare just IRL learned policies

# %%
size_mult = 1.5
plt.rc('axes', titlesize=6*size_mult)     # fontsize of the axes title
plt.rc('axes', labelsize=6*size_mult)    # fontsize of the x and y axes labels
plt.rc('xtick', labelsize=6*size_mult)    # fontsize of the tick labels
plt.rc('ytick', labelsize=6*size_mult)    # fontsize of the tick labels
plt.rc('legend', fontsize=5*size_mult)    # legend fontsize
plt.rc('figure', titlesize=9*size_mult)  # fontsize of the figure title

print('Experiment ID:', exp_info['EXPERIMENT_NAME'])
    
fig, axes, mu_dfs, w_dfs, perf_dfs = plot_source_fair_irl_comparisons(
    feat_objective_set_names=base_exp_info['FEAT_EXP_OBJECTIVE_NAMES'],
#     perf_objective_set_names=base_exp_info['PERF_MEAS_OBJECTIVE_NAMES'],
    perf_objective_set_names=[
        'Acc',
#         'AccPar',
        'DemPar',
        'EqOpp',
        'FPRPar',
        'TNRPar',
#         'FNRPar',
#         'PR_Z0',
#         'PR_Z1',
#         'NR_Z0',
#         'NR_Z1'
#         'TPR_Z0',
#         'TPR_Z1',
#         'TNR_Z0',
#         'TNR_Z1',
#         'FPR_Z0',
#         'FPR_Z1',
#         'FNR_Z0',
#         'FNR_Z1',
        'PredPar',
#         'OppPredPar',
    ],
    expert_algos=[
        'OptAcc',
#         'COMPAS',
        'HardtDemPar',
        'HardtEqOpp',
#         'HardtTNRPar',
#         'RedBoundedGroupLoss',
    ],
    dataset=exp_info['DATASET'],
    demo_producers=[
        'muE',  # source
        'muL (FairIRL)',  # source
    ],
    mu_noise_factor=0,
    perf_noise_factor=0,
    w_noise_factor=0,
    mu_hue_order=[
        'muE',
        'muL (FairIRL)',
        'muL (Beh Clone)',
#         None,
#         None,
#         'muL (FairIRLFO)',
    ],
    perf_hue_order=[
        'Expert',
        'Learned (FairIRL)',
        'Learned (Beh Clone)',
#         None,
#         None,
    ],
    w_hue_order=[
        None,
        'wL (FairIRL)',
#         None,
#         'wL (FairIRLFO)',
    ],
    extra_skip_conditions=skip_by_name,
    min_exp_timestamp=min_exp_timestamp,
    mu_yticks=np.linspace(0, 1, 11).round(1),
    mu_ylim=(0, 1.02),
    mu_whis=[1, 99],
    w_yticks = np.linspace(-1, 1, 21).round(1),
    w_ylim=(-.2, .32),
    perf_ylim=(.45, 1.05),
    perf_yticks=np.linspace(.5, 1, 6).round(1),
    size_mult=size_mult,
    palette=[cp[4], cp[9], cp[6], cp[8]],
    figsize=(18, 15),
)

rotation = 67.5
if len(np.shape(axes)) > 1:
    for ax_i, _ in enumerate(axes[0]):
        axes[0][ax_i].tick_params(axis='x', rotation=rotation)
        axes[1][ax_i].tick_params(axis='x', rotation=rotation)
        axes[2][ax_i].tick_params(axis='x', rotation=rotation)
else:
    axes[0].tick_params(axis='x', rotation=rotation)
    axes[1].tick_params(axis='x', rotation=rotation)
    axes[2].tick_params(axis='x', rotation=rotation)
# Out:
# Experiment ID: boston_to_adult_jan8_44
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 45
#       7 plt.rc('figure', titlesize=9*size_mult)  # fontsize of the figure title
#       9 print('Experiment ID:', exp_info['EXPERIMENT_NAME'])
#      11 fig, axes, mu_dfs, w_dfs, perf_dfs = plot_source_fair_irl_comparisons(
#      12     feat_objective_set_names=base_exp_info['FEAT_EXP_OBJECTIVE_NAMES'],
#      13 #     perf_objective_set_names=base_exp_info['PERF_MEAS_OBJECTIVE_NAMES'],
#      14     perf_objective_set_names=[
#      15         'Acc',
#      16 #         'AccPar',
#      17         'DemPar',
#      18         'EqOpp',
#      19         'FPRPar',
#      20         'TNRPar',
#      21 #         'FNRPar',
#      22 #         'PR_Z0',
#      23 #         'PR_Z1',
#      24 #         'NR_Z0',
#      25 #         'NR_Z1'
#      26 #         'TPR_Z0',
#      27 #         'TPR_Z1',
#      28 #         'TNR_Z0',
#      29 #         'TNR_Z1',
#      30 #         'FPR_Z0',
#      31 #         'FPR_Z1',
#      32 #         'FNR_Z0',
#      33 #         'FNR_Z1',
#      34         'PredPar',
#      35 #         'OppPredPar',
#      36     ],
#      37     expert_algos=[
#      38         'OptAcc',
#      39 #         'COMPAS',
#      40         'HardtDemPar',
#      41         'HardtEqOpp',
#      42 #         'HardtTNRPar',
#      43 #         'RedBoundedGroupLoss',
#      44     ],
# ---> 45     dataset=exp_info['DATASET'],
#      46     demo_producers=[
#      47         'muE',  # source
#      48         'muL (FairIRL)',  # source
#      49     ],
#      50     mu_noise_factor=0,
#      51     perf_noise_factor=0,
#      52     w_noise_factor=0,
#      53     mu_hue_order=[
#      54         'muE',
#      55         'muL (FairIRL)',
#      56         'muL (Beh Clone)',
#      57 #         None,
#      58 #         None,
#      59 #         'muL (FairIRLFO)',
#      60     ],
#      61     perf_hue_order=[
#      62         'Expert',
#      63         'Learned (FairIRL)',
#      64         'Learned (Beh Clone)',
#      65 #         None,
#      66 #         None,
#      67     ],
#      68     w_hue_order=[
#      69         None,
#      70         'wL (FairIRL)',
#      71 #         None,
#      72 #         'wL (FairIRLFO)',
#      73     ],
#      74     extra_skip_conditions=skip_by_name,
#      75     min_exp_timestamp=min_exp_timestamp,
#      76     mu_yticks=np.linspace(0, 1, 11).round(1),
#      77     mu_ylim=(0, 1.02),
#      78     mu_whis=[1, 99],
#      79     w_yticks = np.linspace(-1, 1, 21).round(1),
#      80     w_ylim=(-.2, .32),
#      81     perf_ylim=(.45, 1.05),
#      82     perf_yticks=np.linspace(.5, 1, 6).round(1),
#      83     size_mult=size_mult,
#      84     palette=[cp[4], cp[9], cp[6], cp[8]],
#      85     figsize=(18, 15),
#      86 )
#      88 rotation = 67.5
#      89 if len(np.shape(axes)) > 1:
#
# KeyError: 'DATASET'

# %% [markdown]
# # Compare results with target domain

# %% [markdown]
# ### Compare each expert's demo vs learned

# %%
## plt.rc('axes', titlesize=11)     # fontsize of the axes title
size_mult = 1.
sns.set_style('whitegrid')
plt.rc('axes', titlesize=10*size_mult)     # fontsize of the axes title
plt.rc('axes', labelsize=10*size_mult)    # fontsize of the x and y axes labels
plt.rc('xtick', labelsize=10*size_mult)    # fontsize of the tick labels
plt.rc('ytick', labelsize=10*size_mult)    # fontsize of the tick labels
plt.rc('legend', fontsize=9*size_mult)    # legend fontsize
plt.rc('figure', titlesize=10*size_mult)  # fontsize of the figure title

print('Experiment ID:', exp_info['EXPERIMENT_NAME'])

fig, axes, mu_dfs, w_dfs, perf_dfs = plot_results_target_domain(
    feat_objective_set_names=exp_info['FEAT_EXP_OBJECTIVE_NAMES'],
#     perf_objective_set_names=base_exp_info['PERF_MEAS_OBJECTIVE_NAMES'],
    perf_objective_set_names=[
        'Acc',
        'DemPar',
        'EqOpp',
        'FPRPar',
        'TNRPar',
        'FNRPar',
#         'PR_Z0',
#         'PR_Z1',
#         'NR_Z0',
#         'NR_Z1'
#         'TPR_Z0',
#         'TPR_Z1',
#         'TNR_Z0',
#         'TNR_Z1',
#         'FPR_Z0',
#         'FPR_Z1',
#         'FNR_Z0',
#         'FNR_Z1',
        'PredPar',
        'NegPredPar',
    ],
#     expert_algos=np.unique([exp['EXPERT_ALGO'] for exp in experiments]),
    expert_algos=[
#         'OptAcc',
        'HardtDemPar',
        'HardtEqOpp',
        'HardtEqOdds',
        'BoundedGroupLoss',
#         'COMPAS',
    ],
    source_dataset=experiments[-1]['DATASET'],
    target_dataset=experiments[-1]['TARGET_DATASET'],
#     source_dataset=None,
#     target_dataset=None,
    mu_noise_factor=0,
    extra_skip_conditions=skip_by_name,
    min_exp_timestamp=min_exp_timestamp,
    mu_yticks=np.linspace(0, 1, 11).round(1),
    mu_ylim=(0, 1.0),
    mu_whis=[1, 99],
    perf_noise_factor=0,
    perf_ylim=(.4, 1),
    perf_yticks=np.linspace(0, 1, 11).round(2),
    size_mult=size_mult,
    mu_hue_order=[  
#         'muE',
        'muE_target',
#         'muL (FairIRL)',
#         'muL (FairIRLFO)',
        'muL_target FairIRL',

    ],
    perf_hue_order=[
#         'Expert (source)',
        'Expert (target)',
        'FairIRL Learned (target)',
        'Beh Clone Learned (target)',
    ],
    figsize=(10, 6),
    perf_leg_ax=0,
)

rotation = 60
if len(np.shape(axes)) > 1:
    for ax_i, _ in enumerate(axes[0]):
        axes[0][ax_i].tick_params(axis='x', rotation=rotation)
        axes[1][ax_i].tick_params(axis='x', rotation=rotation)
else:
    axes[0].tick_params(axis='x', rotation=rotation)
    axes[1].tick_params(axis='x', rotation=rotation)
    
    
for i, label in enumerate(axes[1][0].get_legend().get_texts()):
    text = label.get_text()
    label.set_text(text.replace(' (target)', '').replace(' Learned', ''))
    
for i, _ in enumerate(axes[0]):
    labels = [item.get_text() for item in axes[0][i].get_xticklabels()]
#     labels[1] = labels[1].replace('DemPar', 'PRPar')
#     labels[2] = labels[2].replace('EqOpp', 'TPRPar')
    axes[0][i].set_xticklabels(labels)
    
for i, _ in enumerate(axes[1]):
    labels = [item.get_text() for item in axes[1][i].get_xticklabels()]
#     labels[1] = labels[1].replace('DemPar', 'PRPar')
#     labels[2] = labels[2].replace('EqOpp', 'TPRPar')
    labels[-2] = labels[-2].replace('PredPar', 'PrPar')
    labels[-1] = labels[-1].replace('NegPredPar', 'NPrPar')
    axes[1][i].set_xticklabels(labels)
    
for ax_i, ax in enumerate(axes):
    for plot_i, plot in enumerate(ax):
        title = plot.get_title()
        plot.set_title(title.replace('HardtEqOdds', 'EqOddsRed'))
# Out:
# Experiment ID: ACSIncome_MS_to_MA_jan8_44
# 2024-01-16 12:52:30.csv HardtDemPar Beh Clone 3 result rows
# 2024-01-16 12:53:34.csv HardtDemPar FairIRL 3 result rows
# 2024-01-16 13:07:35.csv HardtDemPar Beh Clone 3 result rows
# 2024-01-16 13:09:30.csv HardtDemPar FairIRL 3 result rows
# 2024-01-16 18:09:49.csv HardtDemPar Beh Clone 5 result rows
# 2024-01-16 18:14:10.csv HardtDemPar FairIRL 2 result rows
# 2024-01-17 09:14:18.csv HardtDemPar Beh Clone 10 result rows
# 2024-01-17 09:23:05.csv HardtDemPar FairIRL 10 result rows
# 2024-01-16 12:53:39.csv HardtEqOpp Beh Clone 3 result rows
# 2024-01-16 12:56:40.csv HardtEqOpp FairIRL 3 result rows
# 2024-01-16 13:09:37.csv HardtEqOpp Beh Clone 3 result rows
# 2024-01-16 13:12:25.csv HardtEqOpp FairIRL 2 result rows
# 2024-01-16 18:14:19.csv HardtEqOpp Beh Clone 5 result rows
# 2024-01-16 18:20:10.csv HardtEqOpp FairIRL 3 result rows
# 2024-01-17 09:23:23.csv HardtEqOpp Beh Clone 10 result rows
# 2024-01-17 09:34:18.csv HardtEqOpp FairIRL 8 result rows
# 2024-01-16 12:56:46.csv HardtEqOdds Beh Clone 3 result rows
# 2024-01-16 12:59:08.csv HardtEqOdds FairIRL 1 result rows
# 2024-01-16 13:12:33.csv HardtEqOdds Beh Clone 3 result rows
# 2024-01-16 13:15:34.csv HardtEqOdds FairIRL 1 result rows
# 2024-01-16 18:20:19.csv HardtEqOdds Beh Clone 5 result rows
# 2024-01-16 18:24:59.csv HardtEqOdds FairIRL 1 result rows
# 2024-01-17 09:34:37.csv HardtEqOdds Beh Clone 10 result rows
# 2024-01-17 09:45:15.csv HardtEqOdds FairIRL 7 result rows
# 2024-01-16 13:00:17.csv BoundedGroupLoss Beh Clone 3 result rows
# 2024-01-16 13:03:48.csv BoundedGroupLoss FairIRL 1 result rows
# 2024-01-16 13:16:49.csv BoundedGroupLoss Beh Clone 3 result rows
# 2024-01-16 17:23:58.csv BoundedGroupLoss Beh Clone 3 result rows
# 2024-01-16 18:27:09.csv BoundedGroupLoss Beh Clone 5 result rows
# 2024-01-16 18:37:12.csv BoundedGroupLoss FairIRL 1 result rows
# 2024-01-17 09:49:03.csv BoundedGroupLoss Beh Clone 10 result rows
# 2024-01-17 10:04:36.csv BoundedGroupLoss FairIRL 7 result rows
# SOURCE DATASET: ACSIncome__MS
# TARGET DATASET: ACSIncome__MA

# %% [markdown]
# ### Compare just IRL learned policies

# %%
size_mult = 1.5
plt.rc('axes', titlesize=9*size_mult)     # fontsize of the axes title
plt.rc('axes', labelsize=9*size_mult)    # fontsize of the x and y axes labels
plt.rc('xtick', labelsize=7*size_mult)    # fontsize of the tick labels
plt.rc('ytick', labelsize=7*size_mult)    # fontsize of the tick labels
plt.rc('legend', fontsize=6*size_mult)    # legend fontsize
plt.rc('figure', titlesize=9*size_mult)  # fontsize of the figure title

print('Experiment ID:', exp_info['EXPERIMENT_NAME'])
    
fig, axes, mu_dfs, w_dfs, perf_dfs = plot_target_fair_irl_comparisons(
    feat_objective_set_names=exp_info['FEAT_EXP_OBJECTIVE_NAMES'],
    perf_objective_set_names=exp_info['PERF_MEAS_OBJECTIVE_NAMES'],
    expert_algos=[
        'OptAcc',
        'COMPAS',
        'HardtDemPar',
        'HardtEqOpp',
#         'HardtTNRPar',
#         'RedBoundedGroupLoss',
    ],
    dataset=exp_info['DATASET'],
    feat_demo_producers=[
#         'muE',
#         'muE_target',
#         'muL_source FairIRL',
        'muL_target FairIRL',
    ],
    perf_demo_producers=[
        'Acc',
#         'AccPar',
        'DemPar',
        'EqOpp',
        'FPRPar',
        'TNRPar',
#         'FNRPar',
#         'PR_Z0',
#         'PR_Z1',
#         'NR_Z0',
#         'NR_Z1'
#         'TPR_Z0',
#         'TPR_Z1',
#         'TNR_Z0',
#         'TNR_Z1',
#         'FPR_Z0',
#         'FPR_Z1',
#         'FNR_Z0',
#         'FNR_Z1',
        'PredPar',
#         'OppPredPar',
    ],
    w_demo_producers=[
      'wL (FairIRL)',
    ],
    mu_noise_factor=.001,
    perf_noise_factor=.001,
    w_noise_factor=.001,
    mu_hue_order=[
        'muE',
        'muL (FairIRL)',
        'muL (Beh Clone)',
#         None,
#         None,
#         'muL (FairIRLFO)',
    ],
    perf_hue_order=['muE', 'muL (FairIRL)', 'muL (FairIRLFO)'],
    w_hue_order=[None, 'wL (FairIRL)', 'wL (FairIRLFO)'],
    extra_skip_conditions=skip_by_name,
    min_exp_timestamp=min_exp_timestamp,
    max_mu_value=1,
    min_w_value=-.05,
    mu_yticks=np.linspace(0, 1, 11).round(1),
    mu_ylim=(0, 1.05),
    mu_whis=[1, 99],
    w_yticks = np.linspace(-1, 1, 101).round(1),
    w_ylim=(-.05, .35),
    perf_ylim=(.45, 1.05),
    perf_yticks=np.linspace(0, 1, 11).round(1),
    size_mult=size_mult,
    figsize=(14, 10)
)
print(f"Source Dataset: {exp_info['DATASET']}")
print(f"Target Dataset: {exp_info['TARGET_DATASET']}")
# Out:
# Experiment ID: adult_to_boston_jan8_44
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1866], line 11
#       7 plt.rc('figure', titlesize=9*size_mult)  # fontsize of the figure title
#       9 print('Experiment ID:', exp_info['EXPERIMENT_NAME'])
# ---> 11 fig, axes, mu_dfs, w_dfs, perf_dfs = plot_target_fair_irl_comparisons(
#      12     feat_objective_set_names=exp_info['FEAT_EXP_OBJECTIVE_NAMES'],
#      13     perf_objective_set_names=exp_info['PERF_MEAS_OBJECTIVE_NAMES'],
#      14     expert_algos=[
#      15         'OptAcc',
#      16         'COMPAS',
#      17         'HardtDemPar',
#      18         'HardtEqOpp',
#      19 #         'HardtTNRPar',
#      20 #         'RedBoundedGroupLoss',
#      21     ],
#      22     dataset=exp_info['DATASET'],
#      23     feat_demo_producers=[
#      24 #         'muE',
#      25 #         'muE_target',
#      26 #         'muL_source FairIRL',
#      27         'muL_target FairIRL',
#      28     ],
#      29     perf_demo_producers=[
#      30         'Acc',
#      31 #         'AccPar',
#      32         'DemPar',
#      33         'EqOpp',
#      34         'FPRPar',
#      35         'TNRPar',
#      36 #         'FNRPar',
#      37 #         'PR_Z0',
#      38 #         'PR_Z1',
#      39 #         'NR_Z0',
#      40 #         'NR_Z1'
#      41 #         'TPR_Z0',
#      42 #         'TPR_Z1',
#      43 #         'TNR_Z0',
#      44 #         'TNR_Z1',
#      45 #         'FPR_Z0',
#      46 #         'FPR_Z1',
#      47 #         'FNR_Z0',
#      48 #         'FNR_Z1',
#      49         'PredPar',
#      50 #         'OppPredPar',
#      51     ],
#      52     w_demo_producers=[
#      53       'wL (FairIRL)',
#      54     ],
#      55     mu_noise_factor=.001,
#      56     perf_noise_factor=.001,
#      57     w_noise_factor=.001,
#      58     mu_hue_order=[
#      59         'muE',
#      60         'muL (FairIRL)',
#      61         'muL (Beh Clone)',
#      62 #         None,
#      63 #         None,
#      64 #         'muL (FairIRLFO)',
#      65     ],
#      66     perf_hue_order=['muE', 'muL (FairIRL)', 'muL (FairIRLFO)'],
#      67     w_hue_order=[None, 'wL (FairIRL)', 'wL (FairIRLFO)'],
#      68     extra_skip_conditions=skip_by_name,
#      69     min_exp_timestamp=min_exp_timestamp,
#      70     max_mu_value=1,
#      71     min_w_value=-.05,
#      72     mu_yticks=np.linspace(0, 1, 11).round(1),
#      73     mu_ylim=(0, 1.05),
#      74     mu_whis=[1, 99],
#      75     w_yticks = np.linspace(-1, 1, 101).round(1),
#      76     w_ylim=(-.05, .35),
#      77     perf_ylim=(.45, 1.05),
#      78     perf_yticks=np.linspace(0, 1, 11).round(1),
#      79     size_mult=size_mult,
#      80     figsize=(14, 10)
#      81 )
#      82 print(f"Source Dataset: {exp_info['DATASET']}")
#      83 print(f"Target Dataset: {exp_info['TARGET_DATASET']}")
#
# File ~/my/research/experiments/irl/experiment_utils.py:3171, in plot_target_fair_irl_comparisons(feat_objective_set_names, perf_objective_set_names, expert_algos, dataset, feat_demo_producers, perf_demo_producers, w_demo_producers, mu_noise_factor, perf_noise_factor, w_noise_factor, mu_hue_order, perf_hue_order, w_hue_order, irl_methods_to_exclude, extra_skip_conditions, extra_title, min_exp_timestamp, max_exp_timestamp, min_mu_value, max_mu_value, min_w_value, min_perf_value, mu_yticks, perf_yticks, w_yticks, mu_ylim, perf_ylim, w_ylim, mu_whis, perf_whis, w_whis, size_mult, figsize)
#    3167 mu_df['Value'] += mu_noise_factor*(np.random.rand(len(mu_df)) - .5)
#    3168 mu_df['Value'] = mu_df['Value'].clip(0, 1)
#    3169 mu_df = mu_df[
#    3170     mu_df['Demo Producer'].str.contains('muE')
# -> 3171     | mu_df['Demo Producer'].str.contains('muL_target')
#    3172 ]
#    3173 perf_df = pd.DataFrame(perf_rows, columns=perf_cols)
#    3174 perf_df['Value'] += perf_noise_factor*(np.random.rand(len(perf_df)) - .5)
#
# ValueError: No results for provided config.

# %% [markdown]
# # Convergence

# %% [markdown]
# ### Plot feature expectation euclidean distance vs iterations

# %%
from scipy.optimize import curve_fit
sns.set_style('whitegrid')

def plot_error_vs_numberiters(exp_params_to_match, learn_idx_start=2, agg='mean'):
    """
    Plots the error (Euclidean distance between muE and muL) versus
    the number of IRL iterations.
    """
    path_prefix = './../../data/experiment_output/fair_irl/'
    exp_info_files = sorted(os.listdir(f"{path_prefix}/exp_info/"))
    exp_conv_files = sorted(os.listdir(f"{path_prefix}/exp_conv_details/"))
    
    first_conv_file = exp_conv_files[0].replace('csv', '').split('__', 1)[0]
    
    # Started logging conv files after info files, so need to find the
    # point where started logging both.
    info_file_start = 0
    for i, info_file in enumerate(exp_info_files):
        if info_file.replace('.json', '') == first_conv_file:
            info_file_start = i
            break
        
    conv_files = []
    
    # Aggregate all of the files that match the specified inputs
    for expert in exp_params_to_match['EXPERT_ALGO']:
        info_file_offset = info_file_start

        for conv_file in exp_conv_files:
            conv = pd.read_csv(
                f"{path_prefix}/exp_conv_details/{conv_file}",
                index_col=None,
            )
            
            found_info_file = False
            for info_file in exp_info_files[info_file_offset:]:
                if found_info_file:
                    break
                    
                info_filename = info_file.replace('.json', '')
                conv_filename = conv_file.replace('csv', '').split('__', 1)[0]
                if info_filename == conv_filename:
                    params_do_not_match = False
                    info = json.load(open(f"{path_prefix}/exp_info/{info_file}"))
                    
                    for k in exp_params_to_match:
                        if info['EXPERT_ALGO'] != expert or info[k] not in exp_params_to_match[k]:
                            params_do_not_match = True
                            break
                            
                    if not params_do_not_match:
                        found_info_file = True
                        correct_info_file = True
                        conv['expert_algo'] = expert
                        conv_files.append(conv)
                        
    # Transform agg results into dataframe
    conv_files = pd.concat(conv_files)
    
    # Plot
    fig, ax = plt.subplots(1, 1, figsize=(5, 2))
    
    for expert_i, expert in enumerate(exp_params_to_match['EXPERT_ALGO']):
        itergroups = (
            conv_files
            .query('expert_algo == @expert')
            .query('mu_delta_l2norm_hold < 1e10')  # Filter out inf
            # .groupby(['learn_idx'])[['mu_delta_l2norm_hold']]
            .groupby(['learn_idx'])[['t']]
            .agg([agg])
            # ['mu_delta_l2norm_hold']
            ['t']
            .reset_index()
        )
        itergroups = itergroups.query('learn_idx >= @learn_idx_start')
        
        if len(itergroups) == 0:
            continue
        
        # Plot scatterplot
        # label = f"{expert}: $||\mu^L-\mu^E||_2$"
        label = expert
        label = label.replace('HardtEqOdds', 'EqOddsRed')
        ax.scatter(
            itergroups['learn_idx'],
            itergroups[agg],
            alpha=.8,
            s=5,
        )
        
        try:
            # Fit the decay curve
            def decay_func(x, a, b, c):
                return a * np.exp(-b * x) + c
            x_data = itergroups['learn_idx']
            y_data = itergroups[agg]
            popt, pcov = curve_fit(
                decay_func,
                x_data,
                y_data,
                # p0=(3, .25, .25)
            )

            # Plot decay curve "best fit" line
            x_fit = np.linspace(min(x_data), max(x_data), 100)
            y_fit = decay_func(x_fit, *popt)
            ax.plot(x_fit, y_fit, label=label, c=cp[expert_i], alpha=.85)
        except(RuntimeError) as e:
            logging.info(f"Could not fit `curve_fit() for {expert}")
            logging.info(e)
        
    ax.legend(
        ncol=1,
        # columnspacing=.5,
        # labelspacing=.1,
    )
    ax.set_xlabel('Number of iterations')
    # ax.set_ylabel('Feat Exp Euclidean dist')
    ax.set_ylabel('Error (SVM margin)')
    plt.show()
    
    return (fig, ax), conv_files

# %%
exp_params_to_match = {
    'EXPERIMENT_NAME': ['adult_to_boston_error_inc_stop_57'],
    'EXPERT_ALGO': [
        'HardtDemPar',
        'HardtEqOpp',
        'HardtEqOdds',
        'BoundedGroupLoss',
        
    ],
    'IRL_METHOD': 'FairIRL',
}
(fig, ax), conv_files = plot_error_vs_numberiters(
    exp_params_to_match,
    agg='mean',
)

# %% [markdown]
# ### Plot runtime vs input size

# %%
def plot_runtime_vs_inputsize(x_label, exp_params_to_match, x_plot_label=None, info_file_start=3_000, max_x=np.inf):
    """
    Plots the runtime vs input size.
    """
    path_prefix = './../../data/experiment_output/fair_irl/'
    exp_info_files = sorted(os.listdir(f"{path_prefix}/exp_info/"))
    exp_result_files = sorted(os.listdir(f"{path_prefix}/exp_results/"))
        
    results = []
    
    # Aggregate all of the files that match the specified inputs
    for expert in exp_params_to_match['EXPERT_ALGO']:
        info_file_offset = info_file_start

        for info_file in exp_info_files:
            if '.json' not in info_file:
                continue
                
            info_filepath = f"{path_prefix}/exp_info/{info_file}"
            info = json.load(open(info_filepath))
            
            params_do_not_match = False
            for k in exp_params_to_match:
                if info['EXPERT_ALGO'] != expert or info[k] not in exp_params_to_match[k]:
                    params_do_not_match = True
                    break
             
            if not params_do_not_match:
                result_file = f"{path_prefix}/exp_results/{info_file.replace('.json', '.csv')}"  
                result = pd.read_csv(result_file, index_col=None)         
                result['expert_algo'] = expert
                results.append(result)
                        
    # Transform agg results into dataframe
    results = pd.concat(results).reset_index(drop=True)
    
    # I had a bug where this was negative for a few trials
    results = results.query('source_irl_loop_runtime > 0')
    
    results = results[results[x_label] < max_x]
    results = results.query("source_trial_inputsize > 500 or source_irl_loop_runtime < 10")
    
    fig, ax = plt.subplots(1, 1, figsize=(5, 2))
    for expert_i, expert in enumerate(exp_params_to_match['EXPERT_ALGO']):
        label = expert
        label = label.replace('HardtEqOdds', 'EqOddsRed')
        
        r = results.query('expert_algo == @expert')
        ax.scatter(
            r[x_label],
            r['source_trial_runtime'],
            s=10,
            alpha=1,
        )
        
        # Fit the decay curve
        def log_func(x, a, b, c):
            return a*np.log(b * x) + c
        
        def exp_fun(x, a, b, c):
            return a * np.exp(b * x) + c
        
        def poly_fun(x, a, b, c):
            return np.polyval([a,b,c], x)
        
        x_data = r[x_label].astype(float)
        y_data = r['source_irl_loop_runtime']
        
        try:
            popt, pcov = curve_fit(
                poly_fun,
                x_data,
                y_data,
                p0=(.03, .1, 0)
            )
            # Plot decay curve "best fit" line
            x_fit = np.linspace(min(x_data), max(x_data), 100)
            y_fit = poly_fun(x_fit, *popt)
            ax.plot(x_fit, y_fit, label=label, c=cp[expert_i], alpha=.85)
            print(popt)
            
        except(Exception) as e:
            logging.info(f"Error when calling `curve_fit()`: {e}")
        
    # ax.set_xlabel('Model input size (distinct $(z,x)$ pairs)')
    ax.set_xlabel(x_plot_label)
    ax.set_ylabel('Runtime (seconds)')
    ax.legend(
        ncol=1,
        # columnspacing=.6,
        # labelspacing=.2,
    )
    
    
    return (fig, ax), results

# %%
exp_params_to_match = {
    'EXPERIMENT_NAME': ['adult_to_boston_error_inc_stop_57'],
    'EXPERT_ALGO': [
        'HardtDemPar',
        'HardtEqOpp',
        'HardtEqOdds',
        'BoundedGroupLoss',
    ],
    'IRL_METHOD': 'FairIRL',
}

(fig, ax), results = plot_runtime_vs_inputsize(
    'source_trial_inputsize',
    exp_params_to_match,
    max_x=25_000,
)
# Out:
# [ 7.85891000e-05 -4.11645846e-02  1.23182128e+01]
# [ 4.39027198e-05 -6.57952776e-03  1.03346584e+01]
# [ 1.01251615e-04 -1.26995052e-01  3.70789582e+01]
# [ 6.69121013e-05 -4.07139491e-02  1.71759939e+01]

# %% [markdown]
# # Scratch

# %%
exp_info = dict(base_exp_info)
exp_info['FEAT_EXP_OBJECTIVE_NAMES'] = [
    'TPR_Z0', 'TPR_Z1',
#     'TNR_Z0', 'TNR_Z1',
    'FPR_Z0', 'FPR_Z1',
#     'FNR_Z0', 'FNR_Z1',
#     'Acc',
#     'DemPar',
#     'EqOpp',
#     'PredPar',
]
exp_info['RESTRICT_Y_ACTION'] = True

X, y, ft = generate_compas_dataset(20_000)
# X, y, ft = generate_adult_dataset(20_000)

# Initiate objectives
objectives = []
for obj_name in exp_info['FEAT_EXP_OBJECTIVE_NAMES']:
    objectives.append(OBJ_LOOKUP_BY_NAME[obj_name]())
feat_obj_set = ObjectiveSet(objectives)
del objectives
# Reset the objective set since they get fitted in each trial run
feat_obj_set.reset()


X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=.2,
)
del X, y


# Fit a classifier that predicts `y` from `X`.
clf = sklearn_clf_pipeline(
    feature_types=ft,
    clf_inst=RandomForestClassifier(),
)
clf.fit(X_train, y_train)

# Initiate variables needed to run IRL Loop
x_cols = (
    ft['boolean']
    + ft['categoric']
    + ft['continuous']
)
x_cols.remove('z')

# wi = [.2, .3, -.15, -.2]  # .598, .881, .906
# wi = [.195, .22, -.205, -.17]  # .608, .984, .994
wi = [.2, .3, .15, .2]  # .598, .881, .906
# wi = [.9, .02, .02]


reward_weights = { obj.name: wi[j] for j, obj in enumerate(feat_obj_set.objectives) }

test_df = X_test.copy()
test_df['y'] = y_test
# test_df = X_train.copy()
# test_df['y'] = y_train
# test_df['y'] = clf.predict(X_test)

clf_pol = compute_optimal_policy(
    clf_df=test_df,  # NOT the dataset used to train the C_{Y_Z,X} clf
    clf=clf,
    x_cols=x_cols,
    obj_set=feat_obj_set,
    reward_weights=reward_weights,
    skip_error_terms=True,
    method=exp_info['METHOD'],
    min_freq_fill_pct=exp_info['MIN_FREQ_FILL_PCT'],
)

demo = generate_demo(clf_pol, X_train, y_train, can_observe_y=False)
muj = feat_obj_set.compute_demo_feature_exp(demo)
print(f"\t\t muL = {np.round(muj, 3)}")


print('Acc', AccuracyObjective().compute_feat_exp(demo).round(3))
print('DemPar', DemographicParityObjective().compute_feat_exp(demo).round(3))
print('EqOpp', EqualOpportunityObjective().compute_feat_exp(demo).round(3))

display(demo.groupby(['z', 'y'])[['yhat']].agg(['count', 'mean', 'sum']))
display(demo.groupby(['z'])[['yhat']].agg(['count', 'mean', 'sum']))
# Out:
# 		 muL = [0.748 0.776 0.503 0.396]
# Acc 0.605
# DemPar 0.947
# EqOpp 0.972
#      yhat
#     count      mean     sum
# z y
# 0 0  4608  0.496745  2289.0
#   1  4768  0.748112  3567.0
# 1 0  2650  0.604151  1601.0
#   1  1970  0.776142  1529.0
#    yhat
#   count      mean     sum
# z
# 0  9376  0.624573  5856.0
# 1  4620  0.677489  3130.0

# %% [markdown]
# # HW Scratch

# %%
from math import comb
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ### Problem 1

# %%
def expected_4_cliques(n, p):
    return comb(n, 4) * p**6

# %%
def thresh_4_clique(n):
    return comb(n, 4)**(-(1/6))

# %%
expected_4_cliques(int(1e15), p=1e-9)
# Out:
# 41666.66666666643

# %%
sns.set_style('darkgrid')
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
cp = sns.color_palette()

for i, n in enumerate([100_000, 1_000_000, 10_000_000]):
    x = np.linspace(0, .0005, 501)
    y = [expected_4_cliques(n, p) for p in x]
    ax.plot(x, y, label=f"n={n:,}", c=cp[i])
    ax.set_xlabel('p(n)')
    ax.set_ylabel('E[4-cliques]')
    print(n, thresh_4_clique(n))
    
    thresh = n**(-2/3)
    threshx = [thresh for _ in range(10)]
    threshy = np.linspace(0, 1e4, 10)
    ax.plot(threshx, threshy, ls='--', label=f"n^(-2/3) = {thresh:.6f}", c=cp[i])
    
    x2 = np.linspace(0, .95*ax.get_xlim()[1], 2)
    y2 = .05*np.ones(2)
    ax.plot(x2, y2, ls='--', lw=.5, c='gray')

# ax.set_xscale('log')
ax.set_yscale('log')
ax.legend()
pass
# Out:
# 100000 0.0007883266647717149
# 1000000 0.0001698383027949114
# 10000000 3.659052019222436e-05

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 4))
x1 = [100, 1_000, 10_000, 100_000]
y1 = [comb(n, 4) for n in x1]
x2 = np.linspace(0, 1, 101)
y2 = [p**6 for p in x2]
ax.plot(x1, y1, label='Combinations of 4 cliques')
# ax.plot(x2, y2, label='p^6(n)')
ax.legend()

# %%
comb(1000, 4) * 2**(-(comb(4, 2)))
# Out:
# 647142574.21875

# %%
2**(-(comb(4, 2)))
# Out:
# 0.015625

# %% [markdown]
# ### Problem 4

# %%
def prob_vertex_has_deg_k(n, k, p):
    return comb(n, k) * (p**k) * (1-p)**(n-k)

# %%
k_range = [
    3,
    int(np.log(n)),
    int(np.sqrt(n)),
    int(n-1),
]
n = 1_000
d = 100
p = d / n

for k in k_range:
    output = n * comb(n, k) * (p**k)
    print(k, ':', output)
# Out:
# 3 : 166167000.00000003
# 6 : 1368173298991.5005
# 31 : 7.602322407769473e+30
# 999 : 0.0
